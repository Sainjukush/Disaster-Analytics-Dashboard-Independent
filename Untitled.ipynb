# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("synthetic_disaster_events_2025.csv")

# %%
df.head()
# Out:
#    event_id      disaster_type location  latitude  longitude        date  \
# 0         1           Wildfire    Chile       -35        -72  2025-08-27
# 1         2          Hurricane    India        22         78  2023-05-29
# 2         3  Volcanic Eruption    Italy        42         11  2023-01-15
# 3         4            Drought    Chile       -33        -70  2024-02-08
# 4         5  Volcanic Eruption   Turkey        39         37  2023-12-23
#
#    severity_level  affected_population  estimated_economic_loss_usd  \
# 0               8                31104                    2,768,213
# 1               5                29340                    5,996,227
# 2               7                34804                    9,222,541
# 3               8                31191                    1,827,703
# 4               8                46284                   13,435,921
#
#    response_time_hours aid_provided  infrastructure_damage_index  \
# ...

# %%
df.columns
# Out:
# Index(['event_id', 'disaster_type', 'location', 'latitude', 'longitude',
#        'date', 'severity_level', 'affected_population',
#        'estimated_economic_loss_usd', 'response_time_hours', 'aid_provided',
#        'infrastructure_damage_index', 'is_major_disaster'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   event_id                     20000 non-null  int64
#  1   disaster_type                20000 non-null  object
#  2   location                     20000 non-null  object
#  3   latitude                     20000 non-null  float64
#  4   longitude                    20000 non-null  float64
#  5   date                         20000 non-null  object
#  6   severity_level               20000 non-null  int64
#  7   affected_population          20000 non-null  int64
#  8   estimated_economic_loss_usd  20000 non-null  float64
#  9   response_time_hours          20000 non-null  float64
#  10  aid_provided                 20000 non-null  object
#  11  infrastructure_damage_index  20000 non-null  float64
#  12  is_major_disaster            20000 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# event_id                       0
# disaster_type                  0
# location                       0
# latitude                       0
# longitude                      0
# date                           0
# severity_level                 0
# affected_population            0
# estimated_economic_loss_usd    0
# response_time_hours            0
# aid_provided                   0
# infrastructure_damage_index    0
# is_major_disaster              0
# dtype: int64

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    event_id      disaster_type location  latitude  longitude       date  \
# 0         1           Wildfire    Chile       -35        -72 2025-08-27
# 1         2          Hurricane    India        22         78 2023-05-29
# 2         3  Volcanic Eruption    Italy        42         11 2023-01-15
# 3         4            Drought    Chile       -33        -70 2024-02-08
# 4         5  Volcanic Eruption   Turkey        39         37 2023-12-23
#
#    severity_level  affected_population  estimated_economic_loss_usd  \
# 0               8                31104                    2,768,213
# 1               5                29340                    5,996,227
# 2               7                34804                    9,222,541
# 3               8                31191                    1,827,703
# 4               8                46284                   13,435,921
#
#    response_time_hours aid_provided  infrastructure_damage_index  \
# ...

# %% [markdown]
# 1. Which types of disasters cause the highest economic loss?

# %%
df1= round((df.groupby('disaster_type')['estimated_economic_loss_usd'].sum()),5)
pd.options.display.float_format = '{:,.0f}'.format

# %%
df1.sort_values(ascending=False)
# Out:
# disaster_type
# Earthquake          14,339,311,149
# Landslide           13,981,221,492
# Hurricane           13,916,903,531
# Drought             13,831,854,096
# Volcanic Eruption   13,820,939,149
# Wildfire            13,602,514,413
# Flood               13,128,709,086
# Name: estimated_economic_loss_usd, dtype: float64

# %%
plt.figure(figsize=(10,5))
ax = df1_sorted.plot(kind='bar')

# Labels and title
plt.xlabel("Disaster Type")
plt.ylabel("Total Economic Loss (USD)")
plt.title("Disaster Type vs Total Economic Loss")
plt.xticks(rotation=0)


max_val = df1_sorted.max()
plt.ylim(0, max_val * 1.15)


for i, value in enumerate(df1_sorted):
    ax.text(
        i,
        value + max_val * 0.02,
        f"{value:,.0f}",
        ha='center',
        va='bottom',
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Which countries experience the most frequent disasters?

# %%
df2 = df.groupby('location')['disaster_type'].count()
df2
# Out:
# location
# Chile          2515
# India          2583
# Indonesia      2530
# Italy          2485
# Japan          2477
# Philippines    2453
# Turkey         2515
# USA            2442
# Name: disaster_type, dtype: int64
